# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import plotly.express as px
from plotly.subplots import make_subplots
import cufflinks as cf
import seaborn as sns
cf.go_offline()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
diamonds_train = pd.read_csv("data/diamonds_train.csv")
diamonds_train = diamonds_train.drop(["index_id", "city_id", "city_id.1", "index_id.1", "cut_id", "color_id", "color_id.1", "clarity_id", "cut_id.1", "index_id.2", "clarity_id.1"], axis = 1)

# %%
#Analizo la relación entre los distintos tipos de corte y el precio

plt.figure(figsize=(10, 6))
sns.boxplot(data=diamonds_train, x='cut', y='price')
plt.title('Boxplot de Precio por Corte')
plt.xlabel('Corte')
plt.ylabel('Precio')
plt.show()

"""Curiosamente, el corte de peor calidad (fair) parte siempre
de un precio más alto."""

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=diamonds_train, x='color', y='price')
plt.title('Boxplot de Precio por Corte')
plt.xlabel('Color')
plt.ylabel('Precio')
plt.show()

"""De nuevo, el peor color (J) es el que parte de un mayor precio 
inicial. Tal vez haya que modificar las labels del encoding. El D, 
que en teoría es el mejor color, tiene un rango de precio mucho más
pequeño"""

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=diamonds_train, x='clarity', y='price')
plt.title('Boxplot de Precio por Clarity')
plt.xlabel('Clarity')
plt.ylabel('Precio')
plt.show()
"""De nuevo, los dos peores (I1, SI1) tienen precios más elevados."""

# %%
"""Voy a ver cuáles tienen mayor relación con un precio elevado
dentro de cada categoría para modificar el label encoding y que
tenga sentido."""

# %%
diamonds_train["cut_encoded"] = 0 

for i, r in diamonds_train.iterrows():
    if r["cut"] == "Fair":
        diamonds_train.at[i, "cut_encoded"] = 1
    elif r["cut"] == "Good":
        diamonds_train.at[i, "cut_encoded"] = 2
    elif r["cut"] == "Very Good":
        diamonds_train.at[i, "cut_encoded"] = 3
    elif r["cut"] == "Premium":
        diamonds_train.at[i, "cut_encoded"] = 4
    elif r["cut"] == "Ideal":
        diamonds_train.at[i, "cut_encoded"] = 5
diamonds_train
# Out:
#        price  carat       city color        cut  depth  table     x     y  \
# 0       4268   1.21      Dubai     J    Premium   62.4   58.0  6.83  6.79
# 1        505   0.32   Kimberly     H  Very Good   63.0   57.0  4.35  4.38
# 2       2686   0.71  Las Vegas     G       Fair   65.5   55.0  5.62  5.53
# 3        738   0.41   Kimberly     D       Good   63.8   56.0  4.68  4.72
# 4       4882   1.02      Dubai     G      Ideal   60.5   59.0  6.55  6.51
# ...      ...    ...        ...   ...        ...    ...    ...   ...   ...
# 40450  10070   1.34    Antwerp     G      Ideal   62.7   57.0  7.10  7.04
# 40451  12615   2.02     Madrid     F       Good   57.1   60.0  8.31  8.25
# 40452   5457   1.01   Kimberly     H      Ideal   62.7   56.0  6.37  6.42
# 40453    456   0.33   Kimberly     J      Ideal   61.9   54.3  4.45  4.47
# 40454   6232   1.24     London     I      Ideal   62.0   58.0  6.83  6.88
#
#           z clarity  cut_encoded
# 0      4.25     VS2            4
# 1      2.75     VS2            3
# 2      3.65     VS1            1
# 3      3.00     SI1            2
# 4      3.95     SI1            5
# ...     ...     ...          ...
# 40450  4.43     VS1            5
# 40451  4.73     SI2            2
# 40452  4.01     SI1            5
# 40453  2.76     VS1            5
# 40454  4.25     SI1            5
#
# [40455 rows x 12 columns]

# %%
diamonds_train["clarity_encoded"] = 0 

for i, r in diamonds_train.iterrows():
    if r["clarity"] == "I1":
        diamonds_train.at[i, "clarity_encoded"] = 1
    elif r["clarity"] == "SI2":
        diamonds_train.at[i, "clarity_encoded"] = 2
    elif r["clarity"] == "SI1":
        diamonds_train.at[i, "clarity_encoded"] = 3
    elif r["clarity"] == "VS2":
        diamonds_train.at[i, "clarity_encoded"] = 4
    elif r["clarity"] == "VS1":
        diamonds_train.at[i, "clarity_encoded"] = 5
    elif r["clarity"] == "VVS2":
        diamonds_train.at[i, "clarity_encoded"] = 6
    elif r["clarity"] == "VVS1":
        diamonds_train.at[i, "clarity_encoded"] = 7
    elif r["clarity"] == "IF":
        diamonds_train.at[i, "clarity_encoded"] = 8
diamonds_train
# Out:
#        price  carat       city color        cut  depth  table     x     y  \
# 0       4268   1.21      Dubai     J    Premium   62.4   58.0  6.83  6.79
# 1        505   0.32   Kimberly     H  Very Good   63.0   57.0  4.35  4.38
# 2       2686   0.71  Las Vegas     G       Fair   65.5   55.0  5.62  5.53
# 3        738   0.41   Kimberly     D       Good   63.8   56.0  4.68  4.72
# 4       4882   1.02      Dubai     G      Ideal   60.5   59.0  6.55  6.51
# ...      ...    ...        ...   ...        ...    ...    ...   ...   ...
# 40450  10070   1.34    Antwerp     G      Ideal   62.7   57.0  7.10  7.04
# 40451  12615   2.02     Madrid     F       Good   57.1   60.0  8.31  8.25
# 40452   5457   1.01   Kimberly     H      Ideal   62.7   56.0  6.37  6.42
# 40453    456   0.33   Kimberly     J      Ideal   61.9   54.3  4.45  4.47
# 40454   6232   1.24     London     I      Ideal   62.0   58.0  6.83  6.88
#
#           z clarity  cut_encoded  clarity_encoded
# 0      4.25     VS2            4                4
# 1      2.75     VS2            3                4
# 2      3.65     VS1            1                5
# 3      3.00     SI1            2                3
# 4      3.95     SI1            5                3
# ...     ...     ...          ...              ...
# 40450  4.43     VS1            5                5
# 40451  4.73     SI2            2                2
# 40452  4.01     SI1            5                3
# 40453  2.76     VS1            5                5
# 40454  4.25     SI1            5                3
#
# [40455 rows x 13 columns]

# %%
diamonds_train["color_encoded"] = 0 

for i, r in diamonds_train.iterrows():
    if r["color"] == "J":
        diamonds_train.at[i, "color_encoded"] = 1
    elif r["color"] == "I":
        diamonds_train.at[i, "color_encoded"] = 2
    elif r["color"] == "H":
        diamonds_train.at[i, "color_encoded"] = 3
    elif r["color"] == "G":
        diamonds_train.at[i, "color_encoded"] = 4
    elif r["color"] == "F":
        diamonds_train.at[i, "color_encoded"] = 5
    elif r["color"] == "E":
        diamonds_train.at[i, "color_encoded"] = 6
    elif r["color"] == "D":
        diamonds_train.at[i, "color_encoded"] = 7
diamonds_train
# Out:
#        price  carat       city color        cut  depth  table     x     y  \
# 0       4268   1.21      Dubai     J    Premium   62.4   58.0  6.83  6.79
# 1        505   0.32   Kimberly     H  Very Good   63.0   57.0  4.35  4.38
# 2       2686   0.71  Las Vegas     G       Fair   65.5   55.0  5.62  5.53
# 3        738   0.41   Kimberly     D       Good   63.8   56.0  4.68  4.72
# 4       4882   1.02      Dubai     G      Ideal   60.5   59.0  6.55  6.51
# ...      ...    ...        ...   ...        ...    ...    ...   ...   ...
# 40450  10070   1.34    Antwerp     G      Ideal   62.7   57.0  7.10  7.04
# 40451  12615   2.02     Madrid     F       Good   57.1   60.0  8.31  8.25
# 40452   5457   1.01   Kimberly     H      Ideal   62.7   56.0  6.37  6.42
# 40453    456   0.33   Kimberly     J      Ideal   61.9   54.3  4.45  4.47
# 40454   6232   1.24     London     I      Ideal   62.0   58.0  6.83  6.88
#
#           z clarity  cut_encoded  clarity_encoded  color_encoded
# 0      4.25     VS2            4                4              1
# 1      2.75     VS2            3                4              3
# 2      3.65     VS1            1                5              4
# 3      3.00     SI1            2                3              7
# 4      3.95     SI1            5                3              4
# ...     ...     ...          ...              ...            ...
# 40450  4.43     VS1            5                5              4
# 40451  4.73     SI2            2                2              5
# 40452  4.01     SI1            5                3              3
# 40453  2.76     VS1            5                5              1
# 40454  4.25     SI1            5                3              2
#
# [40455 rows x 14 columns]

# %%
diamonds_train = diamonds_train.drop(["city", "color", "cut","clarity"], axis=1)

# %%
diamonds_test = pd.read_csv("data/diamonds_test.csv")

# %%
diamonds_test["cut_encoded"] = 0 

for i, r in diamonds_test.iterrows():
    if r["cut"] == "Fair":
        diamonds_test.at[i, "cut_encoded"] = 1
    elif r["cut"] == "Good":
        diamonds_test.at[i, "cut_encoded"] = 2
    elif r["cut"] == "Very Good":
        diamonds_test.at[i, "cut_encoded"] = 3
    elif r["cut"] == "Premium":
        diamonds_test.at[i, "cut_encoded"] = 4
    elif r["cut"] == "Ideal":
        diamonds_test.at[i, "cut_encoded"] = 5
diamonds_test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city  cut_encoded
# 0          Amsterdam            3
# 1              Surat            5
# 2           Kimberly            4
# 3           Kimberly            3
# 4          Amsterdam            3
# ...              ...          ...
# 13480      Amsterdam            5
# 13481  New York City            5
# 13482       Tel Aviv            5
# 13483          Surat            3
# 13484  New York City            5
#
# [13485 rows x 12 columns]

# %%
diamonds_test["clarity_encoded"] = 0 

for i, r in diamonds_test.iterrows():
    if r["clarity"] == "I1":
        diamonds_test.at[i, "clarity_encoded"] = 1
    elif r["clarity"] == "SI2":
        diamonds_test.at[i, "clarity_encoded"] = 2
    elif r["clarity"] == "SI1":
        diamonds_test.at[i, "clarity_encoded"] = 3
    elif r["clarity"] == "VS2":
        diamonds_test.at[i, "clarity_encoded"] = 4
    elif r["clarity"] == "VS1":
        diamonds_test.at[i, "clarity_encoded"] = 5
    elif r["clarity"] == "VVS2":
        diamonds_test.at[i, "clarity_encoded"] = 6
    elif r["clarity"] == "VVS1":
        diamonds_test.at[i, "clarity_encoded"] = 7
    elif r["clarity"] == "IF":
        diamonds_test.at[i, "clarity_encoded"] = 8
diamonds_test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city  cut_encoded  clarity_encoded
# 0          Amsterdam            3                3
# 1              Surat            5                5
# 2           Kimberly            4                3
# 3           Kimberly            3                3
# 4          Amsterdam            3                5
# ...              ...          ...              ...
# 13480      Amsterdam            5                3
# 13481  New York City            5                4
# 13482       Tel Aviv            5                5
# 13483          Surat            3                2
# 13484  New York City            5                6
#
# [13485 rows x 13 columns]

# %%
diamonds_test["color_encoded"] = 0 

for i, r in diamonds_test.iterrows():
    if r["color"] == "J":
        diamonds_test.at[i, "color_encoded"] = 1
    elif r["color"] == "I":
        diamonds_test.at[i, "color_encoded"] = 2
    elif r["color"] == "H":
        diamonds_test.at[i, "color_encoded"] = 3
    elif r["color"] == "G":
        diamonds_test.at[i, "color_encoded"] = 4
    elif r["color"] == "F":
        diamonds_test.at[i, "color_encoded"] = 5
    elif r["color"] == "E":
        diamonds_test.at[i, "color_encoded"] = 6
    elif r["color"] == "D":
        diamonds_test.at[i, "color_encoded"] = 7
diamonds_test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city  cut_encoded  clarity_encoded  color_encoded
# 0          Amsterdam            3                3              5
# 1              Surat            5                5              1
# 2           Kimberly            4                3              3
# 3           Kimberly            3                3              5
# 4          Amsterdam            3                5              5
# ...              ...          ...              ...            ...
# 13480      Amsterdam            5                3              6
# 13481  New York City            5                4              2
# 13482       Tel Aviv            5                5              5
# 13483          Surat            3                2              5
# 13484  New York City            5                6              2
#
# [13485 rows x 14 columns]

# %%
diamonds_test = diamonds_test.drop(["city", "color", "cut","clarity", "id"], axis=1)

# %%
diamonds_train.describe().equals(diamonds_test.describe())
# Out:
# False

# %%
diamonds_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13485 entries, 0 to 13484
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carat            13485 non-null  float64
#  1   depth            13485 non-null  float64
#  2   table            13485 non-null  float64
#  3   x                13485 non-null  float64
#  4   y                13485 non-null  float64
#  5   z                13485 non-null  float64
#  6   cut_encoded      13485 non-null  int64
#  7   clarity_encoded  13485 non-null  int64
#  8   color_encoded    13485 non-null  int64
# dtypes: float64(6), int64(3)
# memory usage: 948.3 KB

# %%
diamonds_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            40455 non-null  int64
#  1   carat            40455 non-null  float64
#  2   depth            40455 non-null  float64
#  3   table            40455 non-null  float64
#  4   x                40455 non-null  float64
#  5   y                40455 non-null  float64
#  6   z                40455 non-null  float64
#  7   cut_encoded      40455 non-null  int64
#  8   clarity_encoded  40455 non-null  int64
#  9   color_encoded    40455 non-null  int64
# dtypes: float64(6), int64(4)
# memory usage: 3.1 MB

# %%
#Proporciones de cut_encoded en diamonds_train:

cut_encoded_train_prop = diamonds_train["cut_encoded"].value_counts(normalize=True)
cut_encoded_train_prop
# Out:
# cut_encoded
# 5    0.400939
# 4    0.253615
# 3    0.224818
# 2    0.090545
# 1    0.030083
# Name: proportion, dtype: float64

# %%
#Proporciones de cut_encoded en diamonds_test:

cut_encoded_test_prop = diamonds_test["cut_encoded"].value_counts(normalize=True)
cut_encoded_test_prop
# Out:
# cut_encoded
# 5    0.395328
# 4    0.261846
# 3    0.221505
# 2    0.092176
# 1    0.029143
# Name: proportion, dtype: float64

# %%
"""Más o menos iguales"""
# Out:
# 'Más o menos iguales'

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

#Histogram for every numerical features:

@interact(feature = diamonds_train.select_dtypes(["int64", "float64"]).columns)

def histogram(feature):
    fig = sns.histplot(x=feature, data=diamonds_train)
    fig.set_title(f"Histogram for {feature}")
    fig
# Out:
# interactive(children=(Dropdown(description='feature', options=('price', 'carat', 'depth', 'table', 'x', 'y', '…

# %%
from ipywidgets import interact, interactive, fixed, interact_manual

#Histogram for every numerical features:

@interact(feature = diamonds_test.select_dtypes(["int64", "float64"]).columns)

def histogram(feature):
    fig = sns.histplot(x=feature, data=diamonds_test)
    fig.set_title(f"Histogram for {feature}")
    fig
# Out:
# interactive(children=(Dropdown(description='feature', options=('carat', 'depth', 'table', 'x', 'y', 'z', 'cut_…

# %%
@interact(feature = diamonds_train.select_dtypes(["int64", "float64"]).columns)

def boxplot(feature):
    fig = sns.boxplot(x=feature, data=diamonds_train)
    fig.set_title(f"Distribution for {feature}")
    fig
# Out:
# interactive(children=(Dropdown(description='feature', options=('price', 'carat', 'depth', 'table', 'x', 'y', '…

# %%
@interact(feature = diamonds_test.select_dtypes(["int64", "float64"]).columns)

def boxplot(feature):
    fig = sns.boxplot(x=feature, data=diamonds_test)
    fig.set_title(f"Distribution for {feature}")
    fig
# Out:
# interactive(children=(Dropdown(description='feature', options=('carat', 'depth', 'table', 'x', 'y', 'z', 'cut_…

# %%
diamonds_matrix = diamonds_train.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(diamonds_matrix, annot=True, cmap = "crest")
# Out:
# <Axes: >

# %%
diamonds_matrix = diamonds_test.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(diamonds_matrix, annot=True, cmap = "crest")
# Out:
# <Axes: >
