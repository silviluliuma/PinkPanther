# %%
import pandas as pd

# %% [markdown]
# EXPLORACIÓN Y TRANSFORMACIONES DE DIAMONDS_TRAIN

# %%
diamonds_train = pd.read_csv("data/diamonds_train.csv")
diamonds_train = diamonds_train.drop(["index_id", "city_id", "city_id.1", "index_id.1", "cut_id", "color_id", "color_id.1", "clarity_id", "cut_id.1", "index_id.2", "clarity_id.1"], axis = 1)

# %%
diamonds_train["cut_encoded"] = 0 

for i, r in diamonds_train.iterrows():
    if r["cut"] == "Fair":
        diamonds_train.at[i, "cut_encoded"] = 1
    elif r["cut"] == "Good":
        diamonds_train.at[i, "cut_encoded"] = 2
    elif r["cut"] == "Very Good":
        diamonds_train.at[i, "cut_encoded"] = 3
    elif r["cut"] == "Premium":
        diamonds_train.at[i, "cut_encoded"] = 4
    elif r["cut"] == "Ideal":
        diamonds_train.at[i, "cut_encoded"] = 5
diamonds_train
# Out:
#        price  carat       city color        cut  depth  table     x     y  \
# 0       4268   1.21      Dubai     J    Premium   62.4   58.0  6.83  6.79
# 1        505   0.32   Kimberly     H  Very Good   63.0   57.0  4.35  4.38
# 2       2686   0.71  Las Vegas     G       Fair   65.5   55.0  5.62  5.53
# 3        738   0.41   Kimberly     D       Good   63.8   56.0  4.68  4.72
# 4       4882   1.02      Dubai     G      Ideal   60.5   59.0  6.55  6.51
# ...      ...    ...        ...   ...        ...    ...    ...   ...   ...
# 40450  10070   1.34    Antwerp     G      Ideal   62.7   57.0  7.10  7.04
# 40451  12615   2.02     Madrid     F       Good   57.1   60.0  8.31  8.25
# 40452   5457   1.01   Kimberly     H      Ideal   62.7   56.0  6.37  6.42
# 40453    456   0.33   Kimberly     J      Ideal   61.9   54.3  4.45  4.47
# 40454   6232   1.24     London     I      Ideal   62.0   58.0  6.83  6.88
#
#           z clarity  cut_encoded
# 0      4.25     VS2            4
# 1      2.75     VS2            3
# 2      3.65     VS1            1
# 3      3.00     SI1            2
# 4      3.95     SI1            5
# ...     ...     ...          ...
# 40450  4.43     VS1            5
# 40451  4.73     SI2            2
# 40452  4.01     SI1            5
# 40453  2.76     VS1            5
# 40454  4.25     SI1            5
#
# [40455 rows x 12 columns]

# %%
diamonds_train["clarity_encoded"] = 0 

for i, r in diamonds_train.iterrows():
    if r["clarity"] == "I1":
        diamonds_train.at[i, "clarity_encoded"] = 1
    elif r["clarity"] == "SI2":
        diamonds_train.at[i, "clarity_encoded"] = 2
    elif r["clarity"] == "SI1":
        diamonds_train.at[i, "clarity_encoded"] = 3
    elif r["clarity"] == "VS2":
        diamonds_train.at[i, "clarity_encoded"] = 4
    elif r["clarity"] == "VS1":
        diamonds_train.at[i, "clarity_encoded"] = 5
    elif r["clarity"] == "VVS2":
        diamonds_train.at[i, "clarity_encoded"] = 6
    elif r["clarity"] == "VVS1":
        diamonds_train.at[i, "clarity_encoded"] = 7
    elif r["clarity"] == "IF":
        diamonds_train.at[i, "clarity_encoded"] = 8
diamonds_train
# Out:
#        price  carat       city color        cut  depth  table     x     y  \
# 0       4268   1.21      Dubai     J    Premium   62.4   58.0  6.83  6.79
# 1        505   0.32   Kimberly     H  Very Good   63.0   57.0  4.35  4.38
# 2       2686   0.71  Las Vegas     G       Fair   65.5   55.0  5.62  5.53
# 3        738   0.41   Kimberly     D       Good   63.8   56.0  4.68  4.72
# 4       4882   1.02      Dubai     G      Ideal   60.5   59.0  6.55  6.51
# ...      ...    ...        ...   ...        ...    ...    ...   ...   ...
# 40450  10070   1.34    Antwerp     G      Ideal   62.7   57.0  7.10  7.04
# 40451  12615   2.02     Madrid     F       Good   57.1   60.0  8.31  8.25
# 40452   5457   1.01   Kimberly     H      Ideal   62.7   56.0  6.37  6.42
# 40453    456   0.33   Kimberly     J      Ideal   61.9   54.3  4.45  4.47
# 40454   6232   1.24     London     I      Ideal   62.0   58.0  6.83  6.88
#
#           z clarity  cut_encoded  clarity_encoded
# 0      4.25     VS2            4                4
# 1      2.75     VS2            3                4
# 2      3.65     VS1            1                5
# 3      3.00     SI1            2                3
# 4      3.95     SI1            5                3
# ...     ...     ...          ...              ...
# 40450  4.43     VS1            5                5
# 40451  4.73     SI2            2                2
# 40452  4.01     SI1            5                3
# 40453  2.76     VS1            5                5
# 40454  4.25     SI1            5                3
#
# [40455 rows x 13 columns]

# %%
diamonds_train["color_encoded"] = 0 

for i, r in diamonds_train.iterrows():
    if r["color"] == "J":
        diamonds_train.at[i, "color_encoded"] = 1
    elif r["color"] == "I":
        diamonds_train.at[i, "color_encoded"] = 2
    elif r["color"] == "H":
        diamonds_train.at[i, "color_encoded"] = 3
    elif r["color"] == "G":
        diamonds_train.at[i, "color_encoded"] = 4
    elif r["color"] == "F":
        diamonds_train.at[i, "color_encoded"] = 5
    elif r["color"] == "E":
        diamonds_train.at[i, "color_encoded"] = 6
    elif r["color"] == "D":
        diamonds_train.at[i, "color_encoded"] = 7
diamonds_train
# Out:
#        price  carat       city color        cut  depth  table     x     y  \
# 0       4268   1.21      Dubai     J    Premium   62.4   58.0  6.83  6.79
# 1        505   0.32   Kimberly     H  Very Good   63.0   57.0  4.35  4.38
# 2       2686   0.71  Las Vegas     G       Fair   65.5   55.0  5.62  5.53
# 3        738   0.41   Kimberly     D       Good   63.8   56.0  4.68  4.72
# 4       4882   1.02      Dubai     G      Ideal   60.5   59.0  6.55  6.51
# ...      ...    ...        ...   ...        ...    ...    ...   ...   ...
# 40450  10070   1.34    Antwerp     G      Ideal   62.7   57.0  7.10  7.04
# 40451  12615   2.02     Madrid     F       Good   57.1   60.0  8.31  8.25
# 40452   5457   1.01   Kimberly     H      Ideal   62.7   56.0  6.37  6.42
# 40453    456   0.33   Kimberly     J      Ideal   61.9   54.3  4.45  4.47
# 40454   6232   1.24     London     I      Ideal   62.0   58.0  6.83  6.88
#
#           z clarity  cut_encoded  clarity_encoded  color_encoded
# 0      4.25     VS2            4                4              1
# 1      2.75     VS2            3                4              3
# 2      3.65     VS1            1                5              4
# 3      3.00     SI1            2                3              7
# 4      3.95     SI1            5                3              4
# ...     ...     ...          ...              ...            ...
# 40450  4.43     VS1            5                5              4
# 40451  4.73     SI2            2                2              5
# 40452  4.01     SI1            5                3              3
# 40453  2.76     VS1            5                5              1
# 40454  4.25     SI1            5                3              2
#
# [40455 rows x 14 columns]

# %%
diamonds_train = diamonds_train.drop(["city", "color", "cut","clarity"], axis=1)

# %%
diamonds_train
# Out:
#        price  carat  depth  table     x     y     z  cut_encoded  \
# 0       4268   1.21   62.4   58.0  6.83  6.79  4.25            4
# 1        505   0.32   63.0   57.0  4.35  4.38  2.75            3
# 2       2686   0.71   65.5   55.0  5.62  5.53  3.65            1
# 3        738   0.41   63.8   56.0  4.68  4.72  3.00            2
# 4       4882   1.02   60.5   59.0  6.55  6.51  3.95            5
# ...      ...    ...    ...    ...   ...   ...   ...          ...
# 40450  10070   1.34   62.7   57.0  7.10  7.04  4.43            5
# 40451  12615   2.02   57.1   60.0  8.31  8.25  4.73            2
# 40452   5457   1.01   62.7   56.0  6.37  6.42  4.01            5
# 40453    456   0.33   61.9   54.3  4.45  4.47  2.76            5
# 40454   6232   1.24   62.0   58.0  6.83  6.88  4.25            5
#
#        clarity_encoded  color_encoded
# 0                    4              1
# 1                    4              3
# 2                    5              4
# 3                    3              7
# 4                    3              4
# ...                ...            ...
# 40450                5              4
# 40451                2              5
# 40452                3              3
# 40453                5              1
# 40454                3              2
#
# [40455 rows x 10 columns]

# %% [markdown]
# EXPLORACIÓN Y TRANSFORMACIONES DE DIAMONDS_TEST

# %%
diamonds_test = pd.read_csv("data/diamonds_test.csv")

# %%
diamonds_test["cut_encoded"] = 0 

for i, r in diamonds_test.iterrows():
    if r["cut"] == "Fair":
        diamonds_test.at[i, "cut_encoded"] = 1
    elif r["cut"] == "Good":
        diamonds_test.at[i, "cut_encoded"] = 2
    elif r["cut"] == "Very Good":
        diamonds_test.at[i, "cut_encoded"] = 3
    elif r["cut"] == "Premium":
        diamonds_test.at[i, "cut_encoded"] = 4
    elif r["cut"] == "Ideal":
        diamonds_test.at[i, "cut_encoded"] = 5
diamonds_test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city  cut_encoded
# 0          Amsterdam            3
# 1              Surat            5
# 2           Kimberly            4
# 3           Kimberly            3
# 4          Amsterdam            3
# ...              ...          ...
# 13480      Amsterdam            5
# 13481  New York City            5
# 13482       Tel Aviv            5
# 13483          Surat            3
# 13484  New York City            5
#
# [13485 rows x 12 columns]

# %%
diamonds_test["clarity_encoded"] = 0 

for i, r in diamonds_test.iterrows():
    if r["clarity"] == "I1":
        diamonds_test.at[i, "clarity_encoded"] = 1
    elif r["clarity"] == "SI2":
        diamonds_test.at[i, "clarity_encoded"] = 2
    elif r["clarity"] == "SI1":
        diamonds_test.at[i, "clarity_encoded"] = 3
    elif r["clarity"] == "VS2":
        diamonds_test.at[i, "clarity_encoded"] = 4
    elif r["clarity"] == "VS1":
        diamonds_test.at[i, "clarity_encoded"] = 5
    elif r["clarity"] == "VVS2":
        diamonds_test.at[i, "clarity_encoded"] = 6
    elif r["clarity"] == "VVS1":
        diamonds_test.at[i, "clarity_encoded"] = 7
    elif r["clarity"] == "IF":
        diamonds_test.at[i, "clarity_encoded"] = 8
diamonds_test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city  cut_encoded  clarity_encoded
# 0          Amsterdam            3                3
# 1              Surat            5                5
# 2           Kimberly            4                3
# 3           Kimberly            3                3
# 4          Amsterdam            3                5
# ...              ...          ...              ...
# 13480      Amsterdam            5                3
# 13481  New York City            5                4
# 13482       Tel Aviv            5                5
# 13483          Surat            3                2
# 13484  New York City            5                6
#
# [13485 rows x 13 columns]

# %%
diamonds_test["color_encoded"] = 0 

for i, r in diamonds_test.iterrows():
    if r["color"] == "J":
        diamonds_test.at[i, "color_encoded"] = 1
    elif r["color"] == "I":
        diamonds_test.at[i, "color_encoded"] = 2
    elif r["color"] == "H":
        diamonds_test.at[i, "color_encoded"] = 3
    elif r["color"] == "G":
        diamonds_test.at[i, "color_encoded"] = 4
    elif r["color"] == "F":
        diamonds_test.at[i, "color_encoded"] = 5
    elif r["color"] == "E":
        diamonds_test.at[i, "color_encoded"] = 6
    elif r["color"] == "D":
        diamonds_test.at[i, "color_encoded"] = 7
diamonds_test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city  cut_encoded  clarity_encoded  color_encoded
# 0          Amsterdam            3                3              5
# 1              Surat            5                5              1
# 2           Kimberly            4                3              3
# 3           Kimberly            3                3              5
# 4          Amsterdam            3                5              5
# ...              ...          ...              ...            ...
# 13480      Amsterdam            5                3              6
# 13481  New York City            5                4              2
# 13482       Tel Aviv            5                5              5
# 13483          Surat            3                2              5
# 13484  New York City            5                6              2
#
# [13485 rows x 14 columns]

# %%
diamonds_test = diamonds_test.drop(["city", "color", "cut","clarity", "id"], axis=1)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import pickle
import joblib

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from scipy.stats import uniform, randint

# %%
X = diamonds_train.drop(columns=['price'])
y = diamonds_train['price']

scaler = StandardScaler()
scaler.fit(X)

X_standard = scaler.transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_standard, y, test_size=0.2, random_state=42)

regressor = RandomForestRegressor()

param_dist = {'n_estimators': randint(100, 300),  
              'max_depth': [None, 3, 5],  
              'min_samples_split': randint(2, 5), 
              'min_samples_leaf': randint(1, 3), 
              'max_features': ['sqrt']}  

random_search = RandomizedSearchCV(regressor, 
                                   param_distributions=param_dist, 
                                   n_iter=30, 
                                   cv=5, 
                                   verbose=3, 
                                   scoring='neg_root_mean_squared_error', 
                                   random_state=42, 
                                   n_jobs=-1)

random_search.fit(X_train, y_train)

y_pred = random_search.best_estimator_.predict(X_test)

rmse = mean_squared_error(y_test, y_pred, squared=False)
rmse
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# /Users/SilviaMV/miniconda3/envs/sklearn-env/lib/python3.12/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 556.5516100966895

# %%
X_test_standard = scaler.transform(diamonds_test)

y_prediction = random_search.predict(X_test_standard)

# %%
solution = []
for i, value in enumerate(y_prediction):
    solution.append((i,value))

# %%
submission_file = pd.DataFrame(solution)

# %%
submission_file
# Out:
#            0            1
# 0          0  2924.220000
# 1          1  5826.446667
# 2          2  9693.780000
# 3          3  3988.093333
# 4          4  1628.873333
# ...      ...          ...
# 13480  13480  1785.320000
# 13481  13481  2509.906667
# 13482  13482  2974.333333
# 13483  13483  2254.920000
# 13484  13484   872.926667
#
# [13485 rows x 2 columns]

# %%
submission_file.columns = ["id", "price"]

# %%
submission_file.reset_index(drop=True)
# Out:
#           id        price
# 0          0  2924.220000
# 1          1  5826.446667
# 2          2  9693.780000
# 3          3  3988.093333
# 4          4  1628.873333
# ...      ...          ...
# 13480  13480  1785.320000
# 13481  13481  2509.906667
# 13482  13482  2974.333333
# 13483  13483  2254.920000
# 13484  13484   872.926667
#
# [13485 rows x 2 columns]

# %%
submission_file.to_csv("submission_file5.csv", index = False)
# Out:
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=114;, score=-1001.494 total time=   2.5s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=120;, score=-996.096 total time=   2.8s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=174;, score=-1014.077 total time=   3.6s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=199;, score=-1013.301 total time=   4.8s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=199;, score=-982.192 total time=   4.9s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=101;, score=-967.000 total time=   2.5s
# [CV 3/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=291;, score=-1310.500 total time=   4.4s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=121;, score=-576.635 total time=  10.1s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=148;, score=-589.914 total time=  10.0s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=148;, score=-563.949 total time=  10.4s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=274;, score=-1014.862 total time=   6.3s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=274;, score=-970.872 total time=   6.5s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-579.996 total time=  12.5s
# [CV 5/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-561.090 total time=  14.3s
# [CV 2/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=108;, score=-1344.245 total time=   1.7s
# [CV 5/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=108;, score=-1308.246 total time=   1.6s
# [CV 4/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=183;, score=-1297.829 total time=   3.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=271;, score=-988.395 total time=   6.2s
# [CV 1/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=134;, score=-587.003 total time=   9.0s
# [CV 1/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=203;, score=-1317.539 total time=   2.9s
# [CV 3/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=203;, score=-1292.261 total time=   3.1s
# [CV 1/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=153;, score=-1333.933 total time=   2.2s
# [CV 4/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=153;, score=-1292.139 total time=   2.6s
# [CV 3/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=290;, score=-1307.276 total time=   4.8s
# [CV 2/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=289;, score=-1350.972 total time=   4.6s
# [CV 1/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=299;, score=-1315.136 total time=   4.7s
# [CV 5/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=299;, score=-1301.029 total time=   4.8s
# [CV 4/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=289;, score=-1290.590 total time=   5.2s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=181;, score=-595.296 total time=  11.7s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=287;, score=-1006.766 total time=   6.2s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=287;, score=-972.511 total time=   6.0s
# [CV 4/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=114;, score=-556.771 total time=  10.5s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=170;, score=-586.914 total time=  14.7s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=235;, score=-581.841 total time=  15.8s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=180;, score=-1005.590 total time=   3.6s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=180;, score=-1017.554 total time=   3.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=180;, score=-953.983 total time=   4.5s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=114;, score=-983.199 total time=   2.4s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=114;, score=-967.667 total time=   2.7s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=120;, score=-955.946 total time=   2.5s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators=174;, score=-995.293 total time=   3.9s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=199;, score=-1015.989 total time=   4.9s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=101;, score=-1005.460 total time=   2.5s
# [CV 5/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=101;, score=-959.824 total time=   2.5s
# [CV 4/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=291;, score=-1286.658 total time=   4.4s
# [CV 3/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=121;, score=-584.612 total time=   9.9s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=148;, score=-584.297 total time=  10.2s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=269;, score=-1004.321 total time=   6.0s
# [CV 3/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=269;, score=-974.969 total time=   5.4s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=274;, score=-1022.401 total time=   6.4s
# [CV 1/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=163;, score=-1324.037 total time=   2.5s
# [CV 3/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=4, n_estimators=163;, score=-1299.385 total time=   2.8s
# [CV 2/5] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=150;, score=-581.296 total time=  12.5s
# [CV 1/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=266;, score=-1008.169 total time=   5.2s
# [CV 4/5] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=266;, score=-966.409 total time=   6.4s
# [CV 3/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=159;, score=-1297.921 total time=   2.6s
# [CV 1/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=108;, score=-1313.334 total time=   1.7s
# [CV 4/5] END max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=3, n_estimators=108;, score=-1296.769 total time=   1.6s
# [CV 3/5] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=3, n_estimators=183;, score=-1290.367 total time=   3.0s
# [CV 2/5] END max_depth=5, max_features=sqrt, min_samples_leaf=2, min_samples_split=4, n_estimators